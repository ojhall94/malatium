# %% [markdown]
# ## Tabulating our data

# %% [markdown]
# **To Do:**
# - Tidy up headers
# - Add + and - symbols
# - Split over 2 pages
#     - Do this by L & K
# - Add line splitting LK & new stuff
# - Add extra significant figure to modlogg

# %% [markdown]
# We only want to showcase our rotational data output for all stars, not anything else, realistically.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ati = pd.read_csv('../data/atium.csv', index_col=0)

# %%
ati.columns
# Out:
# Index(['KIC', 'Teff', 'age', 'dnu', 'eTeff', 'ednu', 'efeh', 'enumax', 'feh',
#        'loage', 'lomodlogg', 'lomodmass', 'lomodrad', 'modlogg', 'modmass',
#        'modrad', 'numax', 'source', 'upage', 'upmodlogg', 'upmodmass',
#        'upmodrad', 'G', 'bprp', 'hrclass', 'neff_xsplit', 'neff_cosi',
#        'neff_split', 'neff_i', 'l_nus*', 'nus*', 'u_nus*', 'l_cosi', 'cosi',
#        'u_cosi', 'l_nus', 'nus', 'u_nus', 'l_i', 'i', 'u_i', 'fit_numax',
#        'efit_numax', 'fit_d01', 'efit_d01', 'fit_d02', 'efit_d02',
#        'fit_epsilon', 'efit_epsilon', 'V1', 'eV1', 'V2', 'eV2', 'l_P', 'P',
#        'u_P', 'l_vsini', 'vsini', 'u_vsini', 'rhat_flag', 'eye_flag', 'ebprp'],
#       dtype='object')

# %%
ati.head(5)
# Out:
#        KIC  Teff     age      dnu  eTeff   ednu  efeh  enumax   feh   loage  \
# 0  1435467  6326  3.0164   70.369     77  0.034   0.1     6.3  0.01  0.3513
# 1  2837475  6614  1.6270   75.729     77  0.041   0.1     8.2  0.01  0.1757
# 2  3427720  6045  2.2339  120.068     77  0.031   0.1    10.7 -0.06  0.2396
# 3  3456181  6384  2.0901   52.264     77  0.041   0.1     8.3 -0.15  0.1278
# 4  3632418  6193  2.6331   60.704     77  0.019   0.1     3.0 -0.12  0.1757
#
#    ...       eV2        l_P          P        u_P   l_vsini      vsini  \
# 0  ...  0.059509   0.620728   6.541180   0.757775  0.672485  11.669772
# 1  ...  0.046604   0.154079   3.499114   0.172064  0.555348  22.351415
# 2  ...  0.031153  11.821919  31.590512  10.236450  0.305072   1.473754
# 3  ...  0.059344   2.790842  10.699926   2.006340  0.734456   8.634898
# 4  ...  0.034584   0.729588  11.205550   0.624963  0.222056   8.216637
#
#     u_vsini rhat_flag  eye_flag     ebprp
# 0  0.724637       NaN         0  0.000777
# 1  0.540087       NaN         0  0.000587
# 2  0.278017       NaN         0  0.000607
# 3  0.746225       NaN         0  0.000788
# 4  0.228105       NaN         0  0.000551
#
# [5 rows x 62 columns]

# %%
print(ati.columns)
# Out:
# Index(['KIC', 'Teff', 'age', 'dnu', 'eTeff', 'ednu', 'efeh', 'enumax', 'feh',
#        'loage', 'lomodlogg', 'lomodmass', 'lomodrad', 'modlogg', 'modmass',
#        'modrad', 'numax', 'source', 'upage', 'upmodlogg', 'upmodmass',
#        'upmodrad', 'G', 'bprp', 'hrclass', 'neff_xsplit', 'neff_cosi',
#        'neff_split', 'neff_i', 'l_nus*', 'nus*', 'u_nus*', 'l_cosi', 'cosi',
#        'u_cosi', 'l_nus', 'nus', 'u_nus', 'l_i', 'i', 'u_i', 'fit_numax',
#        'efit_numax', 'fit_d01', 'efit_d01', 'fit_d02', 'efit_d02',
#        'fit_epsilon', 'efit_epsilon', 'V1', 'eV1', 'V2', 'eV2', 'l_P', 'P',
#        'u_P', 'l_vsini', 'vsini', 'u_vsini', 'rhat_flag', 'eye_flag', 'ebprp'],
#       dtype='object')

# %%
cols = ['KIC', 'Teff', 'eTeff', 'age', 'loage', 'upage', 'modmass', 'lomodmass', 'upmodmass',
        'modlogg', 'upmodlogg', 'lomodlogg', 
        'nus*', 'l_nus*','u_nus*','i','l_i','u_i', 'P', 'l_P', 'u_P', 'vsini', 'l_vsini', 'u_vsini', 'neff_split',
        'hrclass', 'source']

# %%
out = ati[cols]

# %%
out.sort_values(by='KIC', inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from astropy.table import Table
out = Table.from_pandas(out)

# %%
from astropy import units as u
out['Teff'].info.format = '.0f'
out['Teff'].info.unit = u.K
out['age'].info.format = '.2f'
out['loage'].info.format = '.2f'
out['upage'].info.format = '.2f'
out['modmass'].info.format = '.2f'
out['modmass'].info.unit = u.solMass
out['lomodmass'].info.format = '.2f'
out['upmodmass'].info.format = '.2f'
out['modlogg'].info.format = '.3f'
out['modlogg'].info.unit = u.dex
out['lomodlogg'].info.format = '.3f'
out['upmodlogg'].info.format = '.3f'
out['nus*'].info.format = '.2f'
out['nus*'].info.unit = u.microhertz
out['l_nus*'].info.format = '.2f'
out['u_nus*'].info.format = '.2f'
out['i'] = np.rad2deg(out['i'].data)
out['l_i'] = np.rad2deg(out['l_i'].data)
out['u_i'] = np.rad2deg(out['u_i'].data)
out['i'].info.format = '.1f'
out['i'].info.unit = u.deg
out['l_i'].info.format = '.1f'
out['u_i'].info.format = '.1f'
out['P'].info.format = '.1f'
out['P'].info.unit = u.day
out['l_P'].info.format = '.1f'
out['u_P'].info.format = '.1f'
out['vsini'].info.format = '.1f'
out['vsini'].info.unit = u.km/u.second
out['l_vsini'].info.format = '.2f'
out['u_vsini'].info.format = '.2f'
out['neff_split'].info.format = int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in _auto_format_func(format_, val)
#      89                                      'instead of string type'
# ---> 90                                      .format(val, type(val)))
#      91             except Exception as err:
#
# ValueError: Format function for value 1514 returned <class 'numpy.int64'> instead of string type
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in _pformat_col_iter(self, col, max_lines, show_name, show_unit, outs, show_dtype, show_length)
#     450                 try:
# --> 451                     yield format_col_str(idx)
#     452                 except ValueError:
#
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in format_col_str(idx)
#     442             else:
# --> 443                 return format_func(col_format, col[idx])
#     444
#
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in _auto_format_func(format_, val)
#      98                 raise ValueError('Format function for value {0} failed: {1}'
# ---> 99                                  .format(val, err))
#     100             # If the user-supplied function handles formatting masked elements, use
#
# ValueError: Format function for value 1514 failed: Format function for value 1514 returned <class 'numpy.int64'> instead of string type
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/astropy/table/column.py in format(self, format_string)
#     429             # test whether it formats without error exemplarily
# --> 430             self.pformat(max_lines=1)
#     431         except Exception as err:
#
# /usr/local/lib/python3.7/site-packages/astropy/table/column.py in pformat(self, max_lines, show_name, show_unit, show_dtype, html)
#     530                                    show_unit=show_unit, show_dtype=show_dtype,
# --> 531                                    html=html)
#     532         return lines
#
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in _pformat_col(self, col, max_lines, show_name, show_unit, show_dtype, show_length, html, align)
#     244
# --> 245         col_strs = list(col_strs_iter)
#     246         if len(col_strs) > 0:
#
# /usr/local/lib/python3.7/site-packages/astropy/table/pprint.py in _pformat_col_iter(self, col, max_lines, show_name, show_unit, outs, show_dtype, show_length)
#     455                         'in column "{2}"'.format(col_format, col[idx],
# --> 456                                                  col.info.name))
#     457
#
# ValueError: Unable to parse format string "<class 'int'>" for entry "1514" in column "neff_split"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e2fbb71dbd7e> in <module>
#      32 out['l_vsini'].info.format = '.2f'
#      33 out['u_vsini'].info.format = '.2f'
# ---> 34 out['neff_split'].info.format = int
#
# /usr/local/lib/python3.7/site-packages/astropy/utils/data_info.py in __setattr__(self, attr, value)
#     322         # attribute directly in parent.
#     323         if attr in self.attrs_from_parent and not isinstance(propobj, property):
# --> 324             setattr(self._parent, attr, value)
#     325             return
#     326
#
# /usr/local/lib/python3.7/site-packages/astropy/table/column.py in __setattr__(self, item, value)
#     850         if not isinstance(self, MaskedColumn) and item == "mask":
#     851             raise AttributeError("cannot set mask value to a column in non-masked Table")
# --> 852         super().__setattr__(item, value)
#     853
#     854         if item == 'unit' and issubclass(self.dtype.type, np.number):
#
# /usr/local/lib/python3.7/site-packages/astropy/table/column.py in format(self, format_string)
#     435                 "Invalid format for column '{0}': could not display "
#     436                 "values in this column using this format ({1})".format(
# --> 437                     self.name, err.args[0]))
#     438
#     439     @property
#
# ValueError: Invalid format for column 'neff_split': could not display values in this column using this format (Unable to parse format string "<class 'int'>" for entry "1514" in column "neff_split")

# %%
out
# Out:
# <Table length=95>
#   KIC     Teff eTeff   age    loage  ... u_vsini neff_split hrclass source
#            K                         ...
#  int64   int64 int64 float64 float64 ... float64   int64      str2   str1
# -------- ----- ----- ------- ------- ... ------- ---------- ------- ------
#  1435467  6326    77    3.02    0.35 ...    0.72       1514       H      L
#  2837475  6614    77    1.63    0.18 ...    0.54       1737       H      L
#  3425851  6343    85    3.32    0.64 ...    2.85       2552       H      K
#  3427720  6045    77    2.23    0.24 ...    0.28       4305      MS      L
#  3456181  6384    77    2.09    0.13 ...    0.75       1263       H      L
#  3544595  5669    75    6.63    0.57 ...    0.16       2582      MS      K
#  3632418  6193    77    2.63    0.18 ...    0.23       2572      MS      L
#  3656476  5668    77    8.37    1.57 ...    0.11       5963      MS      L
#  3735871  6107    77    2.35    0.85 ...    0.25       1544      MS      L
#      ...   ...   ...     ...     ... ...     ...        ...     ...    ...
# 11772920  5180   180   10.67    2.97 ...    0.13        296      MS      L
# 11807274  6225    75    3.59    0.45 ...    0.46       2293      MS      K
# 11853905  5781    76    6.71    0.67 ...    0.64        611      MS      K
# 11904151  5647    74   10.23    0.67 ...    0.30        460      MS      K
# 12009504  6179    77    3.97    0.43 ...    0.21       3954      MS      L
# 12069127  6276    77    2.01    0.13 ...   12.63        148       H      L
# 12069424  5825    50    6.67    0.77 ...    0.06          9      MS      L
# 12069449  5750    50    7.39    0.91 ...    0.06       1955      MS      L
# 12258514  5964    77    4.05    0.16 ...    0.25        567      MS      L
# 12317678  6580    77    2.46    0.18 ...    1.01       2031       H      L

# %%
from astropy.io import ascii
ascii.write(out, format='latex')
# Out:
# \begin{table}
# \begin{tabular}{ccccccccccccccccccccccccccc}
# KIC & Teff & eTeff & age & loage & upage & modmass & lomodmass & upmodmass & modlogg & upmodlogg & lomodlogg & nus* & l_nus* & u_nus* & i & l_i & u_i & P & l_P & u_P & vsini & l_vsini & u_vsini & neff_split & hrclass & source \\
#  & $\mathrm{K}$ &  &  &  &  & $\mathrm{M_{\odot}}$ &  &  & $\mathrm{dex}$ &  &  & $\mathrm{\mu Hz}$ &  &  & $\mathrm{{}^{\circ}}$ &  &  & $\mathrm{d}$ &  &  & $\mathrm{km\,s^{-1}}$ &  &  &  &  &  \\
# 1435467 & 6326 & 77 & 3.02 & 0.35 & 0.50 & 1.32 & 0.05 & 0.03 & 4.10 & 0.01 & 0.01 & 1.58 & 0.09 & 0.10 & 63.43 & 6.63 & 10.19 & 6.54 & 0.62 & 0.76 & 11.67 & 0.67 & 0.72 & 1514 & H & L \\
# 2837475 & 6614 & 77 & 1.63 & 0.18 & 0.11 & 1.43 & 0.02 & 0.02 & 4.16 & 0.01 & 0.01 & 3.12 & 0.08 & 0.08 & 70.75 & 4.37 & 6.03 & 3.50 & 0.15 & 0.17 & 22.35 & 0.56 & 0.54 & 1737 & H & L \\
# 3425851 & 6343 & 85 & 3.32 & 0.64 & 0.85 & 1.18 & 0.05 & 0.05 & 4.24 & 0.01 & 0.01 & 1.17 & 0.62 & 0.48 & 60.89 & 22.74 & 20.06 & 8.08 & 2.71 & 8.64 & 6.98 & 3.67 & 2.85 & 2552 & H & K \\
# 3427720 & 6045 & 77 & 2.23 & 0.24 & 0.24 & 1.11 & 0.01 & 0.02 & 4.39 & 0.00 & 0.01 & 0.30 & 0.06 & 0.06 & 56.41 & 23.39 & 22.85 & 31.59 & 11.82 & 10.24 & 1.47 & 0.31 & 0.28 & 4305 & MS & L \\
# 3456181 & 6384 & 77 & 2.09 & 0.13 & 0.13 & 1.50 & 0.02 & 0.03 & 3.95 & 0.01 & 0.01 & 0.92 & 0.08 & 0.08 & 58.21 & 17.72 & 20.42 & 10.70 & 2.79 & 2.01 & 8.63 & 0.73 & 0.75 & 1263 & H & L \\
# 12258514 & 5964 & 77 & 4.05 & 0.16 & 0.18 & 1.26 & 0.01 & 0.01 & 4.13 & 0.00 & 0.00 & 0.39 & 0.03 & 0.04 & 35.00 & 6.62 & 22.86 & 16.75 & 3.63 & 10.02 & 2.76 & 0.25 & 0.25 & 567 & MS & L \\
# 12317678 & 6580 & 77 & 2.46 & 0.18 & 0.22 & 1.34 & 0.01 & 0.04 & 4.05 & 0.01 & 0.01 & 1.27 & 0.14 & 0.13 & 35.26 & 5.16 & 10.08 & 5.20 & 0.92 & 1.80 & 10.11 & 1.09 & 1.01 & 2031 & H & L \\
# \end{tabular}
# \end{table}

# %% [markdown]
# Flags n stuff

# %%
ati
# Out:
#          KIC  Teff      age      dnu  eTeff   ednu  efeh  enumax   feh  \
# 0    1435467  6326   3.0164   70.369     77  0.034  0.10     6.3  0.01
# 1    2837475  6614   1.6270   75.729     77  0.041  0.10     8.2  0.01
# 2    3427720  6045   2.2339  120.068     77  0.031  0.10    10.7 -0.06
# 3    3456181  6384   2.0901   52.264     77  0.041  0.10     8.3 -0.15
# 4    3632418  6193   2.6331   60.704     77  0.019  0.10     3.0 -0.12
# ..       ...   ...      ...      ...    ...    ...   ...     ...   ...
# 90  11295426  5793   6.3100  101.570     74  0.100  0.07    13.0  0.12
# 91  11401755  5911   7.1000   67.900     66  1.200  0.06    44.0 -0.20
# 92  11807274  6225   3.5900   75.710     75  0.310  0.08    56.0  0.00
# 93  11853905  5781   6.7100   74.400     76  1.100  0.10    42.0  0.09
# 94  11904151  5647  10.2300  118.200     74  0.200  0.10   280.0 -0.15
#
#      loage  ...       eV2        l_P          P        u_P   l_vsini  \
# 0   0.3513  ...  0.059509   0.620728   6.541180   0.757775  0.672485
# 1   0.1757  ...  0.046604   0.154079   3.499114   0.172064  0.555348
# 2   0.2396  ...  0.031153  11.821919  31.590512  10.236450  0.305072
# 3   0.1278  ...  0.059344   2.790842  10.699926   2.006340  0.734456
# 4   0.1757  ...  0.034584   0.729588  11.205550   0.624963  0.222056
# ..     ...  ...       ...        ...        ...        ...       ...
# 90  0.3400  ...  0.034581  14.539683  42.614984  11.500965  0.165275
# 91  0.5900  ...  0.052362   4.348832  18.475557   4.689162  0.723918
# 92  0.4500  ...  0.044712   0.527579   7.866009   0.493370  0.480577
# 93  0.6700  ...  0.065522  17.163898  34.004106  18.869753  0.602662
# 94  0.6700  ...  0.062998  12.772054  40.944952  16.540198  0.319387
#
#         vsini   u_vsini rhat_flag  eye_flag     ebprp
# 0   11.669772  0.724637       NaN         0  0.000777
# 1   22.351415  0.540087       NaN         0  0.000587
# 2    1.473754  0.278017       NaN         0  0.000607
# 3    8.634898  0.746225       NaN         0  0.000788
# 4    8.216637  0.228105       NaN         0  0.000551
# ..        ...       ...       ...       ...       ...
# 90   1.203259  0.158763       NaN         0  0.000404
# 91   3.951468  0.632003       NaN         2  0.000569
# 92   9.841369  0.464237       NaN         0  0.000747
# 93   1.845831  0.642007       NaN         0  0.000700
# 94   1.136662  0.302626   rhat_01         2  0.000466
#
# [95 rows x 62 columns]
