# %% [markdown]
# # I want to see which stars have surface rotation rates

# %%
import numpy as np
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import astropy.units as u
from astroquery.vizier import Vizier
from astropy.io import ascii
import warnings
warnings.filterwarnings('ignore')

sns.set_palette('colorblind')
sns.set_context('poster')

# %%
ati = pd.read_csv('../../data/atium.csv',index_col=0)
ati = ati[np.isfinite(ati.nus.values)]
print(f'We have {len(ati)} stars with results')
# Out:
# We have 95 stars with results

# %%
lit = pd.DataFrame()
lit['KIC'] = ati.KIC.copy()
lit['Flag'] = np.nan

# %% [markdown]
# ### Read in the McQuillan+ sample

# %%
cat = Vizier(catalog='J/ApJS/211/24/table1', 
             columns=['KIC', 'Prot', 'e_Prot'])
cat.ROW_LIMIT = -1
mcq = cat.get_catalogs(cat.catalog)[0].to_pandas()
mcq = mcq.rename(columns={'Prot':'McQP','e_Prot':'e_McQP'})

# %%
mcq.head(2)
# Out:
#        KIC    McQP  e_McQP
# 0   892376   1.532   0.007
# 1  1026146  14.891   0.120

# %% [markdown]
# #### Merge results in

# %%
lit = pd.merge(lit, mcq, how='left', on='KIC')

# %%
lit.loc[np.isfinite(lit.McQP), 'Flag'] = 1

# %%
print(f'We have {len(lit[np.isfinite(lit["McQP"])])} / {len(lit)} periods from McQuillan+15')
# Out:
# We have 10 / 95 periods from McQuillan+15

# %% [markdown]
# ### Read in the Santos+19 sample

# %%
santos19 = ascii.read('../../data/santos19.txt').to_pandas()
santos19 = santos19[['KIC', 'Prot', 'E_Prot']]
santos19 = santos19.rename(columns={'Prot':'SP','E_Prot':'e_SP'})

# %%
santos19.head(2)
# Out:
#       KIC     SP  e_SP
# 0  892834  13.61  1.02
# 1  892882  21.96  1.70

# %% [markdown]
# #### Merge results in

# %%
lit = pd.merge(lit, santos19, how='left', on='KIC')
lit.loc[np.isfinite(lit.SP), 'Flag'] = 1

# %%
print(f'We have {len(lit[np.isfinite(lit["SP"])])} / {len(lit)} periods from Santos+19')
# Out:
# We have 0 / 95 periods from Santos+19

# %% [markdown]
# ### Read in the Nielsen+13 sample

# %%
cat = Vizier(catalog='J/A+A/557/L10/table1', 
             columns=['KIC', 'Prot', 'MAD'])
cat.ROW_LIMIT = -1
n13 = cat.get_catalogs(cat.catalog)[0].to_pandas()
n13 = n13.rename(columns={'Prot':'NP','MAD':'e_NP'})

# %%
n13.head(2)
# Out:
#       KIC      NP   e_NP
# 0  891916   5.539  0.191
# 1  892834  13.663  0.098

# %% [markdown]
# #### Merge results in

# %%
lit = pd.merge(lit, n13, how='left', on='KIC')
lit.loc[np.isfinite(lit.NP), 'Flag'] = 1

# %%
print(f'We have {len(lit[np.isfinite(lit["NP"])])} / {len(lit)} periods')
# Out:
# We have 7 / 95 periods

# %% [markdown]
# ### Read in the van Saders+16 sample

# %% [markdown]
# Don't forget to exclude 16 Cyg A & B, which had seismic rotation.

# %%
jvs = pd.read_csv('../../data/jvs_rot.csv', index_col=None)
jvs.dropna(inplace=True)
jvs.KIC = jvs.KIC.astype(int)
jvs = jvs[2:]
jvs.head(2)
# Out:
#        KIC  jvsP  e_jvsP
# 3  3427720  13.9     2.1
# 4  3656476  31.7     3.5

# %% [markdown]
# #### Merge results in

# %%
lit = pd.merge(lit, jvs, how='left', on='KIC')
lit.loc[np.isfinite(lit.jvsP), 'Flag'] = 1
print(f'We have {len(lit[np.isfinite(lit["jvsP"])])} / {len(lit)} periods from van Saders+16')
# Out:
# We have 18 / 95 periods from van Saders+16

# %% [markdown]
# ### Read in the Garcia+14 sample
# This should overlap fully with the van Saders sample.

# %%
cat = Vizier(catalog='	J/A+A/572/A34/table3', 
             columns=['KIC', 'Prot', 'e_Prot'])
cat.ROW_LIMIT = -1
g14 = cat.get_catalogs(cat.catalog)[0].to_pandas()
g14 = g14.rename(columns={'Prot':'GP','e_Prot':'e_GP'})
g14.head(2)
# Out:
#        KIC    GP  e_GP
# 0  1430163  4.16  0.92
# 1  1435467  6.68  0.89

# %% [markdown]
# #### Merge results in

# %%
lit = pd.merge(lit, g14, how='left', on='KIC')
print(f'We have {len(lit[np.isfinite(lit["GP"])])} / {len(lit)} periods from van Garcia+14')
# Out:
# We have 40 / 95 periods from van Garcia+14

# %% [markdown]
# ### Flag stars with rotation rates

# %%
lit['Flag'] = np.nan
l = ['McQP', 'SP','NP','jvsP','GP']

for idx in lit.index:
    if any(np.isfinite(lit[l].loc[idx].values)):
        lit.loc[idx, 'Flag'] = 1
    else:
        lit.loc[idx, 'Flag'] = 0
lit['Flag'] = lit['Flag'].astype(int)

# %% [markdown]
# ### Save out results

# %%
lit.to_csv('../../data/lit_spot_rots.csv')

# %%
lit
# Out:
#          KIC  Flag    McQP  e_McQP  SP  e_SP     NP   e_NP  jvsP  e_jvsP  \
# 0    1435467     1     NaN     NaN NaN   NaN  6.955  0.392   NaN     NaN
# 1    2837475     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 2    3427720     1     NaN     NaN NaN   NaN    NaN    NaN  13.9     2.1
# 3    3456181     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 4    3632418     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 5    3656476     1     NaN     NaN NaN   NaN    NaN    NaN  31.7     3.5
# 6    3735871     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 7    4914923     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 8    5184732     1     NaN     NaN NaN   NaN    NaN    NaN  19.8     2.4
# 9    5773345     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 10   5950854     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 11   6106415     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 12   6116048     1     NaN     NaN NaN   NaN    NaN    NaN  17.3     2.0
# 13   6225718     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 14   6508366     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 15   6603624     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 16   6679371     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 17   6933899     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 18   7103006     1   4.733   0.059 NaN   NaN    NaN    NaN   NaN     NaN
# 19   7106245     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 20   7206837     1   4.072   0.005 NaN   NaN  4.081  0.205   NaN     NaN
# 21   7296438     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 22   7510397     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 23   7680114     1     NaN     NaN NaN   NaN    NaN    NaN  26.3     1.9
# 24   7771282     1  11.744   0.230 NaN   NaN    NaN    NaN   NaN     NaN
# 25   7871531     1  35.361   0.218 NaN   NaN    NaN    NaN  33.7     2.6
# 26   7940546     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 27   7970740     1     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 28   8006161     1     NaN     NaN NaN   NaN    NaN    NaN  29.8     3.1
# 29   8150065     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# ..       ...   ...     ...     ...  ..   ...    ...    ...   ...     ...
# 65  12317678     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 66   3425851     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 67   3544595     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 68   4141376     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 69   4143755     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 70   4349452     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 71   4914423     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 72   5094751     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 73   5866724     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 74   6196457     1     NaN     NaN NaN   NaN    NaN    NaN  16.4     1.2
# 75   6278762     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 76   6521045     1     NaN     NaN NaN   NaN    NaN    NaN  25.3     2.8
# 77   7670943     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 78   8077137     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 79   8292840     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 80   8349582     1     NaN     NaN NaN   NaN    NaN    NaN  51.0     1.5
# 81   8478994     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 82   8494142     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 83   8554498     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 84   8866102     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 85   9592705     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 86  10514430     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 87  10586004     1     NaN     NaN NaN   NaN    NaN    NaN  29.8     1.0
# 88  10666592     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 89  11133306     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 90  11295426     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 91  11401755     1     NaN     NaN NaN   NaN    NaN    NaN  17.2     1.4
# 92  11807274     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 93  11853905     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
# 94  11904151     0     NaN     NaN NaN   NaN    NaN    NaN   NaN     NaN
#
#            GP  e_GP
# 0    6.680000  0.89
# 1    3.680000  0.36
# 2         NaN   NaN
# 3         NaN   NaN
# 4   12.890000  1.38
# 5   31.670000  3.53
# 6   11.530000  1.24
# 7   20.490000  2.82
# 8   19.790001  2.43
# 9   11.570000  1.02
# 10        NaN   NaN
# 11        NaN   NaN
# 12  17.260000  1.96
# 13        NaN   NaN
# 14   3.700000  0.35
# 15        NaN   NaN
# 16   5.480000  0.50
# 17        NaN   NaN
# 18   4.620000  0.48
# 19        NaN   NaN
# 20   4.040000  0.28
# 21  25.160000  2.78
# 22        NaN   NaN
# 23  26.309999  1.86
# 24  11.880000  0.91
# 25  33.720001  2.60
# 26  11.360000  0.95
# 27  17.969999  3.09
# 28  29.790001  3.09
# 29        NaN   NaN
# ..        ...   ...
# 65        NaN   NaN
# 66        NaN   NaN
# 67        NaN   NaN
# 68        NaN   NaN
# 69        NaN   NaN
# 70        NaN   NaN
# 71        NaN   NaN
# 72        NaN   NaN
# 73        NaN   NaN
# 74        NaN   NaN
# 75        NaN   NaN
# 76        NaN   NaN
# 77        NaN   NaN
# 78        NaN   NaN
# 79        NaN   NaN
# 80        NaN   NaN
# 81        NaN   NaN
# 82        NaN   NaN
# 83        NaN   NaN
# 84        NaN   NaN
# 85        NaN   NaN
# 86        NaN   NaN
# 87        NaN   NaN
# 88        NaN   NaN
# 89        NaN   NaN
# 90        NaN   NaN
# 91        NaN   NaN
# 92        NaN   NaN
# 93        NaN   NaN
# 94        NaN   NaN
#
# [95 rows x 12 columns]
